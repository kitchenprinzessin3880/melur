# %%
import csv
import pandas as pd
import re
import numpy as np
import urllib.parse
import requests

# %%
#validate formatted units through ucum service
HOST = 'http://localhost:8080'
UCUM_SERVICE_VALIDATE =HOST+'/pucum/v1/api/validate/'

# %%
df = pd.read_excel('QuantityDimUnit.xlsx', headers=0, delimiter=",",converters={'Dimension':str,'Unit':str})
#df['Quantity']= df['Quantity'].astype(str)
#df['Dimension']= df['Dimension'].astype(str)
#df['UnitName']= df['UnitName'].astype(str)
#df['Unit']= df['Unit'].astype(str)

# %%
df.head(10)
# Out:
#               Quantity  Dimension            UnitName  Unit
# 0    Absolute Humidity        NaN                 NaN   NaN
# 1        Absorbed Dose        NaN                Gray    Gy
# 2        Absorbed Dose        NaN                 Rad   rad
# 3   Absorbed Dose Rate  L^2 T^-3      Gray per Second  Gy/s
# 4         Acceleration        NaN                 NaN   NaN
# 5               Action        NaN                 NaN   NaN
# 6             Activity        NaN           Becquerel    Bq
# 7             Activity        NaN               Curie    Ci
# 8  Amount of Substance         N                 Mole   mol
# 9  Amount of Substance         N   International Unit    IU

# %%
df[df.Unit =='ft-lbf/ft^2']
# Out:
#             Quantity Dimension                    UnitName         Unit
# 932  Energy per Area   M T^-2   Foot Pound per Square Foot  ft-lbf/ft^2
# 937  Energy per Area   M T^-2   Foot Pound per Square Foot  ft-lbf/ft^2
# 942  Energy per Area   M T^-2   Foot Pound per Square Foot  ft-lbf/ft^2

# %%
df.dtypes, df.shape
# Out:
# (Quantity     object
#  Dimension    object
#  UnitName     object
#  Unit         object
#  dtype: object, (2401, 4))

# %%
#df.dropna(subset=['Dimension'], inplace=True)
# remove duplicate rows
df = df.drop_duplicates().reset_index(drop=True)
df.head(10)
# Out:
#               Quantity  Dimension            UnitName  Unit
# 0    Absolute Humidity        NaN                 NaN   NaN
# 1        Absorbed Dose        NaN                Gray    Gy
# 2        Absorbed Dose        NaN                 Rad   rad
# 3   Absorbed Dose Rate  L^2 T^-3      Gray per Second  Gy/s
# 4         Acceleration        NaN                 NaN   NaN
# 5               Action        NaN                 NaN   NaN
# 6             Activity        NaN           Becquerel    Bq
# 7             Activity        NaN               Curie    Ci
# 8  Amount of Substance         N                 Mole   mol
# 9  Amount of Substance         N   International Unit    IU

# %%
df.shape
# Out:
# (1090, 4)

# %%
s ='C^3 m^3 J^-2'
s= s.replace('^','')
s= s.replace(' ','.')
print(s)
# Out:
# C3.m3.J-2

# %%
def pattern_match(m):
    m = m.group(0).replace('-', '.')
    return m

# %%
#reformat units, dimensions
pattern  = re.compile(r'-[A-z]+') #ft^2-s-degF -> ft2.s.degF

def replaceUnits(u):
    if pd.isnull(u):
        return u
    else:
        u= u.replace('^','')
        u1 = pattern.sub(pattern_match, u)
        u2 = re.sub(r'\b(\s)\b', '.', u1)# L^2 M T^-1 -> L2.M.T-1 #\w is equal to [A-Za-z0-9_]
        u2 = u2.replace(" ", "")
        #replace last dot
        u2 = u2.rstrip('.')
        return u2
#t ='cm^2-m' , 'ft^2-s-degF', 'lbf / s', 'L^2 M T^-1 '
replaceUnits('ft-lbf/ft^2')
# Out:
# 'ft.lbf/ft2'

# %%
#df['Dimension'] = df['Dimension'].apply(replaceUnits )
#df['UnitFormatted'] = df['Unit'].apply(replaceUnits )

# %%
invalid_units=[]

# %%
df['DimensionFormatted'] = df['Dimension']
df["UnitFormatted"] = np.nan
df.head()
# Out:
#              Quantity  Dimension         UnitName  Unit DimensionFormatted  \
# 0   Absolute Humidity        NaN              NaN   NaN                NaN
# 1       Absorbed Dose        NaN             Gray    Gy                NaN
# 2       Absorbed Dose        NaN              Rad   rad                NaN
# 3  Absorbed Dose Rate  L^2 T^-3   Gray per Second  Gy/s          L^2 T^-3
# 4        Acceleration        NaN              NaN   NaN                NaN
#
#    UnitFormatted
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
def validateUnit(uom):
    q = UCUM_SERVICE_VALIDATE+ urllib.parse.quote(uom) 
    resp = requests.get(q)
    data = resp.json()
    if (resp.status_code == requests.codes.ok):
        return data['ucum']
    else:
        invalid_units.append(u)
        return None

# %%
for index, row in df.iterrows():
    if pd.notnull(row['Unit']):
        uom = row['Unit']
        ucum = validateUnit(uom)
        if ucum:
            #df.UnitFormatted.iloc[index] = ucum
            df.loc[index,'UnitFormatted'] = ucum
        else:
            formattedUnit = replaceUnits(uom)
            ucum_fmt = validateUnit(formattedUnit)
            if ucum_fmt:
                df.loc[index,'UnitFormatted'] = ucum_fmt

# %%
#units_list = df['UnitFormatted'].unique()
#cleanedList = [x for x in units_list if str(x) != 'nan']
#len(units_list), len(cleanedList)

# %%
invalid_units= list(set(invalid_units))
len(set(invalid_units)), invalid_units
# Out:
# (1, ['m3/K'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1090 entries, 0 to 1089
# Data columns (total 6 columns):
# Quantity              1090 non-null object
# Dimension             717 non-null object
# UnitName              1023 non-null object
# Unit                  795 non-null object
# DimensionFormatted    717 non-null object
# UnitFormatted         617 non-null object
# dtypes: object(6)
# memory usage: 51.2+ KB

# %%
df[df.Unit =='tbsp']
# Out:
#      Quantity Dimension    UnitName  Unit DimensionFormatted UnitFormatted
# 1066   Volume      L^3   Tablespoon  tbsp               L^3       [tbs_us]

# %%
#Replace dimensions
df['DimensionFormatted'] = df['DimensionFormatted'].str.replace('Θ','Q')
df['DimensionFormatted'] = df['DimensionFormatted'].apply(replaceUnits )
df.head(2400)
# Out:
#                                  Quantity          Dimension  \
# 0                       Absolute Humidity                NaN
# 1                           Absorbed Dose                NaN
# 2                           Absorbed Dose                NaN
# 3                      Absorbed Dose Rate          L^2 T^-3
# 4                            Acceleration                NaN
# 5                                  Action                NaN
# 6                                Activity                NaN
# 7                                Activity                NaN
# 8                     Amount of Substance                 N
# 9                     Amount of Substance                 N
# 10      Amount of substance per unit mass            M^-1 N
# 11    Amount of Substance Per Unit Volume            L^-3 N
# 12                                  Angle                NaN
# 13                                  Angle                NaN
# 14                                  Angle                NaN
# 15                                  Angle                NaN
# 16                                  Angle                NaN
# 17                                  Angle                NaN
# 18                   Angular Acceleration            U T^-2
# 19                   Angular Acceleration            U T^-2
# 20                   Angular Acceleration            U T^-2
# 21                      Angular Frequency                NaN
# 22                       Angular Momentum        L^2 M T^-1
# 23                       Angular Momentum        L^2 M T^-1
# 24                       Angular Momentum        L^2 M T^-1
# 25                       Angular Momentum        L^2 M T^-1
# 26                       Angular Velocity            U T^-1
# 27                       Angular Velocity            U T^-1
# 28                       Angular Velocity            U T^-1
# 29                       Angular Velocity            U T^-1
# ...                                   ...                ...
# 1060                               Volume               L^3
# 1061                               Volume               L^3
# 1062                               Volume               L^3
# 1063                               Volume               L^3
# 1064                               Volume               L^3
# 1065                               Volume               L^3
# 1066                               Volume               L^3
# 1067                               Volume               L^3
# 1068                               Volume               L^3
# 1069                               Volume               L^3
# 1070                               Volume               L^3
# 1071                               Volume               L^3
# 1072                               Volume               L^3
# 1073                               Volume               L^3
# 1074                               Volume               L^3
# 1075                               Volume               L^3
# 1076                               Volume               L^3
# 1077                               Volume               L^3
# 1078                 Volume per Unit Time          L^3 T^-1
# 1079                 Volume per Unit Time          L^3 T^-1
# 1080                 Volume per Unit Time          L^3 T^-1
# 1081                 Volume per Unit Time          L^3 T^-1
# 1082                 Volume per Unit Time          L^3 T^-1
# 1083                 Volume per Unit Time          L^3 T^-1
# 1084                 Volume per Unit Time          L^3 T^-1
# 1085                 Volume per Unit Time          L^3 T^-1
# 1086             Volume Thermal Expansion          L^3 Θ^-1
# 1087             Volumetric Heat Capacity  L^-1 M T^-2 Θ^-1
# 1088                            Vorticity                NaN
# 1089                               Weight                NaN
#
#                            UnitName       Unit DimensionFormatted  \
# 0                               NaN        NaN                NaN
# 1                              Gray         Gy                NaN
# 2                               Rad        rad                NaN
# 3                   Gray per Second       Gy/s             L2.T-3
# 4                               NaN        NaN                NaN
# 5                               NaN        NaN                NaN
# 6                         Becquerel         Bq                NaN
# 7                             Curie         Ci                NaN
# 8                              Mole        mol                  N
# 9                International Unit         IU                  N
# 10                Mole per Kilogram     mol/kg              M-1.N
# 11             Mole per Cubic Meter    mol/m^3              L-3.N
# 12                           Radian        rad                NaN
# 13                       Arc Second     arcSec                NaN
# 14                       Arc Minute     arcMin                NaN
# 15                     Degree Angle          °                NaN
# 16                     Second Angle         \t                NaN
# 17                     Minute Angle          '                NaN
# 18        Radian per Second Squared    rad/s^2              U.T-2
# 19        Degree per Second Squared  deg/(s^2)              U.T-2
# 20    Revolution per Second Squared        NaN              U.T-2
# 21                              NaN        NaN                NaN
# 22                     Joule Second        J s           L2.M.T-1
# 23                       Erg Second      erg s           L2.M.T-1
# 24             Electron Volt Second       eV s           L2.M.T-1
# 25          Foot Pound Force Second    lbf / s           L2.M.T-1
# 26                Radian per Second      rad/s              U.T-1
# 27                Radian per second      rad/m              U.T-1
# 28                Degree per Second      deg/s              U.T-1
# 29              Revolution per Hour      rev/h              U.T-1
# ...                             ...        ...                ...
# 1060                 US Liquid Pint         pt                 L3
# 1061                     Board Foot         Bf                 L3
# 1062                 Imperial Ounce         oz                 L3
# 1063                  US Liquid Cup        cup                 L3
# 1064                      US Gallon        gal                 L3
# 1065                         Bushel         bu                 L3
# 1066                     Tablespoon       tbsp                 L3
# 1067                US Liquid Quart         qt                 L3
# 1068                    Cubic Meter        m^3                 L3
# 1069                         Barrel        bbl                 L3
# 1070                        US Peck         pk                 L3
# 1071               Cubic Centimeter       cm^3                 L3
# 1072                    US Dry Pint     dry_pt                 L3
# 1073                          Liter          L                 L3
# 1074                  Imperial Pint         pi                 L3
# 1075                           Cord          C                 L3
# 1076                   US Dry Quart     dry_qt                 L3
# 1077               Cubic Millimeter        m^3                 L3
# 1078          Cubic Foot per Minute   ft^3/min             L3.T-1
# 1079          Cubic Yard per Minute   yd^3/min             L3.T-1
# 1080           US Gallon per Minute    gal/min             L3.T-1
# 1081          Cubic Inch per Minute   in^3/min             L3.T-1
# 1082           Cubic Meter per Hour      m^3/h             L3.T-1
# 1083          Cubic Foot per Second     ft^3/s             L3.T-1
# 1084         Cubic Meter per Second      m^3/s             L3.T-1
# 1085              US Gallon per Day      gal/d             L3.T-1
# 1086         Cubic Meter per Kelvin      m^3/K             L3.Q-1
# 1087   Joule per Cubic Meter Kelvin  J/(m^3 K)      L-1.M.T-2.Q-1
# 1088                            NaN        NaN                NaN
# 1089                            NaN        NaN                NaN
#
#      UnitFormatted
# 0              NaN
# 1               Gy
# 2              rad
# 3             Gy/s
# 4              NaN
# 5              NaN
# 6               Bq
# 7               Ci
# 8              mol
# 9             [IU]
# 10          mol/kg
# 11          mol/m3
# 12             rad
# 13              ''
# 14               '
# 15             deg
# 16             NaN
# 17               '
# 18          rad/s2
# 19        deg/(s2)
# 20             NaN
# 21             NaN
# 22             J.s
# 23           erg.s
# 24            eV.s
# 25      [lbf_av]/s
# 26           rad/s
# 27           rad/m
# 28           deg/s
# 29             NaN
# ...            ...
# 1060            pt
# 1061        [bf_i]
# 1062       [oz_av]
# 1063      [cup_us]
# 1064      [gal_us]
# 1065       [bu_us]
# 1066      [tbs_us]
# 1067       [qt_us]
# 1068            m3
# 1069      [bbl_us]
# 1070       [pk_us]
# 1071           cm3
# 1072  [pt_us]{dry}
# 1073             L
# 1074       [pt_br]
# 1075             C
# 1076  [qt_us]{dry}
# 1077            m3
# 1078       ft3/min
# 1079   [cyd_i]/min
# 1080  [gal_us]/min
# 1081   [cin_i]/min
# 1082          m3/h
# 1083         ft3/s
# 1084          m3/s
# 1085    [gal_us]/d
# 1086          m3/K
# 1087      J/(m3.K)
# 1088           NaN
# 1089           NaN
#
# [1090 rows x 6 columns]

# %%
#dfqudt = df.groupby( [ "Quantity", "Dimension"] )
#dfqudt.head()#
dfqudt = df.groupby('Dimension')['Quantity'].apply(list)
dfqudt.head()

# %%
#df.to_csv('qudt_import.csv', sep='\t', encoding='utf-8',index=False)
